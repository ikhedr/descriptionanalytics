# %%
import csv
with open('D:\\Datta\\_Programming\\Pyhton\\Ticket_Triaging\\stopwords.csv', 'r') as readFile:
    reader = csv.reader(readFile)
    list1 = list(reader)  
ENGLISH_STOP_WORDS = list1[0]
readFile.close()

import pandas as pd
df = pd.read_csv('C:\\Users\\datta.ikhe\\Ramjee_Code\\Ticket_Dump_v2.csv',encoding='latin-1')
df.head()
# Out:
#        Number Assignment_group                    Short_description Task type  \
# 0  INC0010003   L48  Help Desk                                 test  Incident
# 1  INC0010005   L48  Help Desk                               test 2  Incident
# 2  INC0010006   L48  Help Desk                  Test From Prod Env.  Incident
# 3  INC0010012   L48  Help Desk  Software problem - Microsoft Access  Incident
# 4  INC0010013   L48  Help Desk  Software problem - Microsoft Access  Incident
#
#                                          Description
# 0                                         L48 update
# 1  Description: L48 update Product name: BP digit...
# 2  <p>Description: L48 update Product name: Remed...
# 3  Description: Issue: Application Name: Error Me...
# 4  Description: Issue: Application Name: Error Me...

# %%
 #df.dropna(subset=['Description', 'Assignment_group'])
 df.count()
# Out:
# Number               5418
# Assignment_group     5418
# Short_description    5417
# Task type            5418
# Description          5418
# dtype: int64

# %%
def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)
def remove_special_char(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<')
    return re.sub(clean, '', text)
df = df[pd.notnull(df['Description'])]

for index,row in df.iterrows():
    row['Description'] = remove_html_tags(row['Description'])
    row['Description'] = remove_special_char(row['Description'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5418 entries, 0 to 5417
# Data columns (total 5 columns):
# Number               5418 non-null object
# Assignment_group     5418 non-null object
# Short_description    5417 non-null object
# Task type            5418 non-null object
# Description          5418 non-null object
# dtypes: object(5)
# memory usage: 254.0+ KB

# %%
col = ['Assignment_group', 'Description']
df = df[col]

# %%
df.columns
# Out:
# Index(['Assignment_group', 'Description'], dtype='object')

# %%
df.columns = ['Assignment_group', 'Description']

# %%
df['category_id'] = df['Assignment_group'].factorize()[0]
from io import StringIO
category_id_df = df[['Assignment_group', 'category_id']].drop_duplicates().sort_values('category_id')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id', 'Assignment_group']].values)

# %%
df.head(5)
# Out:
#   Assignment_group                    Short_description  category_id
# 0   L48  Help Desk                                 test            0
# 1   L48  Help Desk                               test 2            0
# 2   L48  Help Desk                  Test From Prod Env.            0
# 3   L48  Help Desk  Software problem - Microsoft Access            0
# 4   L48  Help Desk  Software problem - Microsoft Access            0

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,6))
df.groupby('Assignment_group').Description.count().plot.bar(ylim=0)
plt.show()

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

#tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
tfidf = TfidfVectorizer('content', 'utf-8',
                 'strict', None, True,
                 None, None, 'word',
                 ENGLISH_STOP_WORDS, r"(?u)\b\w\w+\b",
                 (1, 1), 1.0, 1,
                 None, None, False,
                 np.int64, 'l2', True, True,
                 False)
features = tfidf.fit_transform(df.Description).toarray()
labels = df.category_id
features.shape
# Out:
# (5418, 44596)

# %%
from sklearn.feature_selection import chi2
import numpy as np

N = 2
for Assignment_group, category_id in sorted(category_to_id.items()):
  features_chi2 = chi2(features, labels == category_id)
  indices = np.argsort(features_chi2[0])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
  bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
  print("# '{}':".format(Assignment_group))
  print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
  print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
# Out:
# # 'Apps Support':
#   . Most correlated unigrams:
#        . act
#        . pi
#   . Most correlated bigrams:
#        .
# # 'Automation':
#   . Most correlated unigrams:
#        . alex
#        . missing
#   . Most correlated bigrams:
#        .
# # 'Azure Infrastructure':
#   . Most correlated unigrams:
#        . azure
#        . firewall
#   . Most correlated bigrams:
#        .
# # 'CHPC Infrastructure':
#   . Most correlated unigrams:
#        . linux
#        . servers
#   . Most correlated bigrams:
#        .
# # 'Database Admins':
#   . Most correlated unigrams:
#        . backup
#        . sql
#   . Most correlated bigrams:
#        .
# # 'L48  Help Desk':
#   . Most correlated unigrams:
#        . review
#        . users
#   . Most correlated bigrams:
#        .
# # 'Office365':
#   . Most correlated unigrams:
#        . office
#        . 365
#   . Most correlated bigrams:
#        .

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(df['Description'], df['Assignment_group'], random_state = 0)
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %%
print(clf.predict(count_vect.transform(["NORMAL : HOU : Upstream App Request ID 52752 for URMS / RDAS (eCORE) - License Completed"])))
# Out:
# ['L48  Help Desk']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC

from sklearn.model_selection import cross_val_score


models = [
    RandomForestClassifier(n_estimators=100, max_depth=4, random_state=0),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=0),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(models)))
entries = []
for model in models:
  model_name = model.__class__.__name__
  accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((model_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])

# %%
import seaborn as sns

sns.boxplot(x='model_name', y='accuracy', data=cv_df)
sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
              size=8, jitter=True, edgecolor="gray", linewidth=2)
plt.show()

# %%
cv_df.groupby('model_name').accuracy.mean()
# Out:
# model_name
# LinearSVC                 0.709273
# LogisticRegression        0.666843
# MultinomialNB             0.624776
# RandomForestClassifier    0.618681
# Name: accuracy, dtype: float64

# %%
from sklearn.model_selection import train_test_split

model = LinearSVC()

X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, labels, df.index, test_size=0.33, random_state=0)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

conf_mat = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8,6))
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=category_id_df.Assignment_group.values, yticklabels=category_id_df.Assignment_group.values)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
from IPython.display import display

for predicted in category_id_df.category_id:
  for actual in category_id_df.category_id:
    if predicted != actual and conf_mat[actual, predicted] >= 6:
      print("'{}' predicted as '{}' : {} examples.".format(id_to_category[actual], id_to_category[predicted], conf_mat[actual, predicted]))
      display(df.loc[indices_test[(y_test == actual) & (y_pred == predicted)]][['Assignment_group', 'Description']])
      print('')
# Out:
# 'Field Services - San Juan' predicted as 'L48  Help Desk' : 59 examples.
#                 Assignment_group  \
# 1654   Field Services - San Juan
# 1259   Field Services - San Juan
# 4917   Field Services - San Juan
# 1297   Field Services - San Juan
# 4311   Field Services - San Juan
# 6635   Field Services - San Juan
# 1091   Field Services - San Juan
# 6399   Field Services - San Juan
# 9507   Field Services - San Juan
# 4512   Field Services - San Juan
# 125    Field Services - San Juan
# 624    Field Services - San Juan
# 3763   Field Services - San Juan
# 4543   Field Services - San Juan
# 312    Field Services - San Juan
# 3771   Field Services - San Juan
# 4697   Field Services - San Juan
# 3803   Field Services - San Juan
# 4668   Field Services - San Juan
# 6556   Field Services - San Juan
# 620    Field Services - San Juan
# 1236   Field Services - San Juan
# 4612   Field Services - San Juan
# 2193   Field Services - San Juan
# 1103   Field Services - San Juan
# ...

# %%
model.fit(features, labels)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
from sklearn.feature_selection import chi2

N = 2
for Product, category_id in sorted(category_to_id.items()):
  indices = np.argsort(model.coef_[category_id])
  feature_names = np.array(tfidf.get_feature_names())[indices]
  unigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 1][:N]
  bigrams = [v for v in reversed(feature_names) if len(v.split(' ')) == 2][:N]
  print("# '{}':".format(Product))
  print("  . Top unigrams:\n       . {}".format('\n       . '.join(unigrams)))
  print("  . Top bigrams:\n       . {}".format('\n       . '.join(bigrams)))
# Out:
# # '.hub Houston':
#   . Top unigrams:
#        . archiving
#        . class
#   . Top bigrams:
#        . wave repair
#        . new outlook
# # 'Apps Support':
#   . Top unigrams:
#        . flowcal
#        . atlas
#   . Top bigrams:
#        . ticket ignore
#        . petra citrix
# # 'Audio - Video':
#   . Top unigrams:
#        . 119
#        . 140
#   . Top bigrams:
#        . control panel
#        . kari hall
# # 'Automation':
#   . Top unigrams:
#        . unknown
#        . wonderware
#   . Top bigrams:
#        . need download
#        . meter id
# # 'Azure Infrastructure':
#   . Top unigrams:
#        . azure
#        . vm
#   . Top bigrams:
#        . 10 215
#        . cloudad account
# # 'Business Intelligence':
#   . Top unigrams:
#        . onemap
#        . dive
#   . Top bigrams:
#        . assign ticket
#        . hi unable
# # 'CHPC Infrastructure':
#   . Top unigrams:
#        . linux
#        . servers
#   . Top bigrams:
#        . rgs span
# ...

# %%
#texts = ["I requested a home loan modification through Bank of America. Bank of America never got back to me.",
#        "It has been difficult for me to find my past due balance. I missed a regular monthly payment",
#         "I can't get the money out of the country.",
#         "I have no money to pay my tuition",
#         "Coinbase closed my account for no reason and furthermore refused to give me a reason despite dozens of request"]
#text_features = tfidf.transform(texts)
#predictions = model.predict(text_features)
#for text, predicted in zip(texts, predictions):
# print('"{}"'.format(text))
# print("  - Predicted as: '{}'".format(id_to_category[predicted]))
# print("")

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, y_pred, 
                                    target_names=df['Assignment_group'].unique()))
# Out:
#                              precision    recall  f1-score   support
#
#              L48  Help Desk       0.66      0.77      0.71      1304
#   Field Services - San Juan       0.58      0.39      0.47       121
#     Field Services - Midcon       0.50      0.10      0.16        21
#                Apps Support       0.63      0.48      0.54       711
#             Database Admins       0.75      0.49      0.59       339
#        Azure Infrastructure       0.46      0.18      0.25       137
#         CHPC Infrastructure       0.50      0.82      0.62       785
#       Business Intelligence       0.45      0.16      0.23        32
#            Network Firewall       0.60      0.16      0.25        38
# Field Services - East Texas       0.60      0.12      0.19        26
#                .hub Houston       0.90      0.75      0.82       394
#                 Mobile Apps       1.00      0.33      0.50         6
#               Audio - Video       1.00      0.20      0.33        20
# ...
